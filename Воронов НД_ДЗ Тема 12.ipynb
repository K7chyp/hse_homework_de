# %%
from kafka import KafkaProducer
import json
import random
from datetime import datetime, timedelta

# Функция для генерации случайной транзакции
def generate_transaction(user_id):
    transaction_id = random.randint(1000, 9999)
    amount = round(random.uniform(50, 2000), 2)
    timestamp = datetime.now() - timedelta(days=random.randint(0, 30), hours=random.randint(0, 23), minutes=random.randint(0, 59))
    location = random.choice(["New York", "Los Angeles", "Chicago", "Houston", "Phoenix"])
    
    return {
        "transaction_id": transaction_id,
        "user_id": user_id,
        "amount": amount,
        "timestamp": timestamp.isoformat(),
        "location": location
    }

# Создаем продюсера
producer = KafkaProducer(
    bootstrap_servers='localhost:9094',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# Генерируем и отправляем транзакции в топик 'transactions'
for user_id in range(1, 101):  # Для 100 пользователей
    for _ in range(10):  # Каждому пользователю по 10 транзакций
        transaction = generate_transaction(user_id)
        producer.send('transactions', transaction)

producer.close()

# %%
import sqlite3

# Создаем базу данных и таблицу клиентов
conn = sqlite3.connect('banking_app.db')
cursor = conn.cursor()

# Создаем таблицу клиентов
cursor.execute('''
CREATE TABLE IF NOT EXISTS clients (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    email TEXT NOT NULL,
    phone TEXT NOT NULL
)
''')

# Генерируем и вставляем данные о клиентах
names = ["Alice", "Bob", "Charlie", "David", "Eve"]
for i in range(1, 101):
    cursor.execute('''
    INSERT INTO clients (name, email, phone) VALUES (?, ?, ?)
    ''', (random.choice(names), f'user{i}@example.com', f'123-456-789{i%10}'))

conn.commit()
conn.close()

# %%
from kafka import KafkaConsumer
import sqlite3

def is_suspicious(transaction):
    # Пример простой логики проверки: если сумма транзакции больше 1000
    return transaction['amount'] > 1000

# Создаем консюмера
consumer = KafkaConsumer(
    'transactions',
    bootstrap_servers='localhost:9094',
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='transaction_group',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# Подключаемся к базе данных
conn = sqlite3.connect('banking_app.db')
cursor = conn.cursor()

# Обрабатываем транзакции
for message in consumer:
    transaction = message.value
    
    # Получаем информацию о клиенте из базы данных
    cursor.execute('SELECT * FROM clients WHERE id = ?', (transaction['user_id'],))
    client = cursor.fetchone()
    
    if client and is_suspicious(transaction):
        print(f'Suspicious transaction detected: {transaction} for client: {client}')

conn.close()
# Out:
# Suspicious transaction detected: {'transaction_id': 3658, 'user_id': 1, 'amount': 1179.12, 'timestamp': '2024-11-28T05:31:30.035280', 'location': 'Los Angeles'} for client: (1, 'Eve', 'user1@example.com', '123-456-7891')
# Suspicious transaction detected: {'transaction_id': 5247, 'user_id': 1, 'amount': 1933.77, 'timestamp': '2024-12-14T01:17:30.035350', 'location': 'Chicago'} for client: (1, 'Eve', 'user1@example.com', '123-456-7891')
# Suspicious transaction detected: {'transaction_id': 3747, 'user_id': 1, 'amount': 1407.48, 'timestamp': '2024-12-01T23:30:30.035418', 'location': 'Houston'} for client: (1, 'Eve', 'user1@example.com', '123-456-7891')
# Suspicious transaction detected: {'transaction_id': 6865, 'user_id': 1, 'amount': 1528.89, 'timestamp': '2024-11-15T05:05:30.035485', 'location': 'Phoenix'} for client: (1, 'Eve', 'user1@example.com', '123-456-7891')
# Suspicious transaction detected: {'transaction_id': 9603, 'user_id': 2, 'amount': 1529.77, 'timestamp': '2024-12-03T00:02:30.035553', 'location': 'Chicago'} for client: (2, 'Bob', 'user2@example.com', '123-456-7892')
# Suspicious transaction detected: {'transaction_id': 3103, 'user_id': 2, 'amount': 1138.8, 'timestamp': '2024-12-01T19:26:30.035690', 'location': 'Los Angeles'} for client: (2, 'Bob', 'user2@example.com', '123-456-7892')
# Suspicious transaction detected: {'transaction_id':
example.com', '123-456-7893')
# Suspicious transaction detected: {'transaction_id': 6491, 'user_id': 93, 'amount': 1118.41, 'timestamp': '2024-12-08T13:47:47.468311', 'location': 'Phoenix'} for client: (93, 'David', 'user93@example.com', '123-456-7893')
# Suspicious transaction detected: {'transaction_id': 2670, 'user_id': 94, 'amount': 1728.5, 'timestamp': '2024-11-21T18:37:47.468376', 'location': 'Chicago'} for client: (94, 'Alice', 'user94@example.com', '123-456-7894')
# Suspicious transaction detected: {'transaction_id': 6519, 'user_id': 94, 'amount': 1023.34, 'timestamp': '2024-12-07T21:21:47.468613', 'location': 'Houston'} for client: (94, 'Alice', 'user94@example.com', '123-456-7894')
# Suspicious transaction detected: {'transaction_id': 5202, 'user_id': 94, 'amount': 1263.6, 'timestamp': '2024-11-27T01:48:47.468667', 'location': 'Chicago'} for client: (94, 'Alice', 'user94@example.com', '123-456-7894')
# Suspicious transaction detected: {'transaction_id': 1328, 'user_id': 94, 'amount': 1344.49, 'timestamp': '2024-11-30T11:10:47.468773', 'location': 'Chicago'} for client: (94, 'Alice', 'user94@example.com', '123-456-7894')
# Suspicious transaction detected: {'transaction_id': 1987, 'user_id': 94, 'amount': 1198.95, 'timestamp': '2024-12-13T07:41:47.468828', 'location': 'Los Angeles'} for client: (94, 'Alice', 'user94@example.com', '123-456-7894')
# Suspicious transaction detected: {'transaction_id': 7790, 'user_id': 94, 'amount': 1683.67, 'timestamp': '2024-11-22T18:13:47.468883', 'location': 'Houston'} for client: (94, 'Alice', 'user94@example.com', '123-456-7894')
# Suspicious transaction detected: {'transaction_id': 4135, 'user_id': 95, 'amount': 1271.9, 'timestamp': '2024-11-23T01:57:47.468939', 'location': 'New York'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 9628, 'user_id': 95, 'amount': 1853.23, 'timestamp': '2024-11-15T07:16:47.468995', 'location': 'Chicago'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 3042, 'user_id': 95, 'amount': 1065.83, 'timestamp': '2024-11-16T13:57:47.469051', 'location': 'Los Angeles'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 5955, 'user_id': 95, 'amount': 1165.93, 'timestamp': '2024-11-15T04:53:47.469219', 'location': 'Phoenix'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 1928, 'user_id': 95, 'amount': 1229.81, 'timestamp': '2024-12-06T00:35:47.469274', 'location': 'Chicago'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 4591, 'user_id': 95, 'amount': 1986.74, 'timestamp': '2024-11-19T18:14:47.469328', 'location': 'Houston'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 9037, 'user_id': 95, 'amount': 1987.39, 'timestamp': '2024-12-04T09:02:47.469436', 'location': 'Phoenix'} for client: (95, 'Bob', 'user95@example.com', '123-456-7895')
# Suspicious transaction detected: {'transaction_id': 4163, 'user_id': 96, 'amount': 1719.1, 'timestamp': '2024-12-02T07:00:47.469827', 'location': 'Phoenix'} for client: (96, 'Alice', 'user96@example.com', '123-456-7896')
# Suspicious transaction detected: {'transaction_id': 7924, 'user_id': 96, 'amount': 1706.95, 'timestamp': '2024-12-09T02:30:47.469889', 'location': 'Chicago'} for client: (96, 'Alice', 'user96@example.com', '123-456-7896')
# Suspicious transaction detected: {'transaction_id': 9764, 'user_id': 96, 'amount': 1414.3, 'timestamp': '2024-11-15T04:15:47.469943', 'location': 'New York'} for client: (96, 'Alice', 'user96@example.com', '123-456-7896')
# Suspicious transaction detected: {'transaction_id': 8006, 'user_id': 97, 'amount': 1413.64, 'timestamp': '2024-12-07T23:22:47.470161', 'location': 'New York'} for client: (97, 'Alice', 'user97@example.com', '123-456-7897')
# Suspicious transaction detected: {'transaction_id': 4434, 'user_id': 97, 'amount': 1807.48, 'timestamp': '2024-11-19T23:38:47.470341', 'location': 'New York'} for client: (97, 'Alice', 'user97@example.com', '123-456-7897')
# Suspicious transaction detected: {'transaction_id': 5730, 'user_id': 97, 'amount': 1646.61, 'timestamp': '2024-11-29T19:25:47.470504', 'location': 'Houston'} for client: (97, 'Alice', 'user97@example.com', '123-456-7897')
# Suspicious transaction detected: {'transaction_id': 5389, 'user_id': 97, 'amount': 1735.37, 'timestamp': '2024-12-06T00:19:47.470660', 'location': 'New York'} for client: (97, 'Alice', 'user97@example.com', '123-456-7897')
# Suspicious transaction detected: {'transaction_id': 2005, 'user_id': 98, 'amount': 1884.53, 'timestamp': '2024-12-09T07:06:47.470723', 'location': 'Chicago'} for client: (98, 'Eve', 'user98@example.com', '123-456-7898')
# Suspicious transaction detected: {'transaction_id': 5259, 'user_id': 98, 'amount': 1344.11, 'timestamp': '2024-11-17T02:27:47.470785', 'location': 'Los Angeles'} for client: (98, 'Eve', 'user98@example.com', '123-456-7898')
# Suspicious transaction detected: {'transaction_id': 9743, 'user_id': 98, 'amount': 1957.72, 'timestamp': '2024-11-25T09:44:47.470904', 'location': 'Houston'} for client: (98, 'Eve', 'user98@example.com', '123-456-7898')
# Suspicious transaction detected: {'transaction_id': 1215, 'user_id': 98, 'amount': 1367.43, 'timestamp': '2024-11-29T00:34:47.471019', 'location': 'Houston'} for client: (98, 'Eve', 'user98@example.com', '123-456-7898')
# Suspicious transaction detected: {'transaction_id': 8561, 'user_id': 98, 'amount': 1612.64, 'timestamp': '2024-12-12T17:43:47.471076', 'location': 'Los Angeles'} for client: (98, 'Eve', 'user98@example.com', '123-456-7898')
# Suspicious transaction detected: {'transaction_id': 5174, 'user_id': 98, 'amount': 1283.06, 'timestamp': '2024-11-14T17:02:47.471245', 'location': 'Houston'} for client: (98, 'Eve', 'user98@example.com', '123-456-7898')
# Suspicious transaction detected: {'transaction_id': 8802, 'user_id': 99, 'amount': 1005.02, 'timestamp': '2024-11-25T00:44:47.471358', 'location': 'Houston'} for client: (99, 'David', 'user99@example.com', '123-456-7899')
# Suspicious transaction detected: {'transaction_id': 3268, 'user_id': 99, 'amount': 1998.94, 'timestamp': '2024-12-01T14:27:47.471643', 'location': 'Phoenix'} for client: (99, 'David', 'user99@example.com', '123-456-7899')
# Suspicious transaction detected: {'transaction_id': 3708, 'user_id': 99, 'amount': 1782.96, 'timestamp': '2024-12-11T22:04:47.471757', 'location': 'Phoenix'} for client: (99, 'David', 'user99@example.com', '123-456-7899')
# Suspicious transaction detected: {'transaction_id': 3881, 'user_id': 99, 'amount': 1768.11, 'timestamp': '2024-11-29T23:29:47.471815', 'location': 'Los Angeles'} for client: (99, 'David', 'user99@example.com', '123-456-7899')
# Suspicious transaction detected: {'transaction_id': 2365, 'user_id': 99, 'amount': 1313.93, 'timestamp': '2024-11-15T18:39:47.471874', 'location': 'Chicago'} for client: (99, 'David', 'user99@example.com', '123-456-7899')
# Suspicious transaction detected: {'transaction_id': 1578, 'user_id': 100, 'amount': 1432.1, 'timestamp': '2024-11-23T01:51:47.471992', 'location': 'Houston'} for client: (100, 'Bob', 'user100@example.com', '123-456-7890')
# Suspicious transaction detected: {'transaction_id': 1692, 'user_id': 100, 'amount': 1353.79, 'timestamp': '2024-12-08T22:54:47.472051', 'location': 'Los Angeles'} for client: (100, 'Bob', 'user100@example.com', '123-456-7890')
# Suspicious transaction detected: {'transaction_id': 3845, 'user_id': 100, 'amount': 1844.06, 'timestamp': '2024-11-27T02:10:47.472212', 'location': 'Phoenix'} for client: (100, 'Bob', 'user100@example.com', '123-456-7890')
# Suspicious transaction detected: {'transaction_id': 7754, 'user_id': 100, 'amount': 1485.19, 'timestamp': '2024-11-24T15:04:47.472345', 'location': 'Phoenix'} for client: (100, 'Bob', 'user100@example.com', '123-456-7890')
# Suspicious transaction detected: {'transaction_id': 4268, 'user_id': 100, 'amount': 1971.41, 'timestamp': '2024-12-05T20:02:47.472521', 'location': 'Los Angeles'} for client: (100, 'Bob', 'user100@example.com', '123-456-7890')

# %%
# Создаем продюсера для подозрительных транзакций
suspicious_producer = KafkaProducer(bootstrap_servers='localhost:9094',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# Обрабатываем транзакции
for message in consumer:
    transaction = message.value
    
    # Получаем информацию о клиенте из базы данных
    cursor.execute('SELECT * FROM clients WHERE id = ?', (transaction['user_id'],))
    client = cursor.fetchone()
    
    if client and is_suspicious(transaction):
        print(f'Suspicious transaction detected: {transaction} for client: {client}')
        
        # Отправляем подозрительную транзакцию в новый поток 'suspicious_transactions'
        suspicious_producer.send('suspicious_transactions', transaction)

suspicious_producer.close()
